# %%
import numpy as np
import random

# %%
def f_identity(A):
    return A

def f_identity_der(A):
    return 1

def f_sigmoid(A):
    s = 1 / (1 + np.exp(-A))
    return s 

def f_sigmoid_der(A):
    s = 1 / (1 + np.exp(-A))
    return s * (1 - s)

     
class hidden_layer:
    def __init__(self, input_dimension, output_dimension, activation_fn, 
                       activation_fn_der, level, sigma = 0.01):
        self.sigma = sigma
        self.name = "Hidden_layer"
        self.level = level 
        self.input_dimension = input_dimension
        self.output_dimension = output_dimension
        self.__activation_fn = activation_fn  
        self.__activation_fn_der = activation_fn_der  
        self.W = np.random.randn(output_dimension,input_dimension) * self.sigma
        self.dW = np.zeros(self.W.shape)
  
    def shape(self):
        return (self.input_dimension, self.output_dimension)
    
    def __linear_activation(self, X):
        return self.W.dot(X)
    
    def __non_linear_activation(self, X):
        Z = self.__activation_fn(X)
        Z[0] = 1 # Clamp to 1
        return Z
    
    def forward(self, Z_prev):
        A  = self.__linear_activation(Z_prev)
        Z  = self.__non_linear_activation(A)
        return Z, A, Z_prev
    
    def backward(self, d_prev, l, layers, caches):
        Z, A, Z_prev = caches[l]
        var = layers[l+1].W.T.dot(d_prev)
        d = np.multiply(var, layers[l].__activation_fn_der(A))
        self.dW = d.dot(Z_prev.T)
        return d    
        
class output_layer:
    def __init__(self, input_dimension, output_dimension, activation_fn, 
                 activation_fn_der, level, sigma = 0.01):
        self.sigma = sigma
        self.name = "Output_layer"
        self.level = level 
        self.input_dimension = input_dimension
        self.output_dimension = output_dimension
        self.__activation_fn = activation_fn
        self.__activation_fn_der = activation_fn_der
        self.W = np.random.randn(output_dimension,input_dimension) * self.sigma
        self.dW = np.zeros(self.W.shape)
        
    def shape(self):
        return (self.input_dimension, self.output_dimension) 
    
    def __linear_activation(self, X):
        return self.W.dot(X)
    
    def __non_linear_activation(self, A):
        return self.__activation_fn(A)

    def forward(self, Z_prev):       
        A  = self.__linear_activation(Z_prev)
        Z  = self.__non_linear_activation(A)
        return Z, A, Z_prev
    
    def backward(self, target, Z_L, A_L, Z_prev):
        error = Z_L - target 
        d_L = np.multiply(error,self.__activation_fn_der(A_L)) # Hadamard product
        self.dW = d_L.dot(Z_prev.T)  #Check batch ops
        return d_L

class mlp: 
    
    def __init__(self, layers_dimensions, sigma = 0.01, verbose = True):
        self.layers_dimensions = layers_dimensions
        self.sigma = sigma
        self.verbose = verbose
        self.layers = []
        for l in range(0, len(layers_dimensions)-2):
            layer = hidden_layer(layers_dimensions[l], layers_dimensions[l+1], f_sigmoid, 
                                 f_sigmoid_der, l+1, sigma)
            self.layers.append(layer)
        l += 1
        layer = output_layer(layers_dimensions[l], layers_dimensions[l+1], f_sigmoid, 
                             f_sigmoid_der,l+1, sigma) # classifier output activation function
        self.layers.append(layer)       
        if self.verbose:
            print("MLP:")
            for l in range(0, len(self.layers)-1):
                    print(f"{self.layers[l].name} {self.layers[l].level}, shape: ({self.layers[l].input_dimension} x {self.layers[l].output_dimension})")
           
            # Output layer
            l += 1
            print(f"{self.layers[l].name} {self.layers[l].level}, shape: ({self.layers[l].input_dimension} x {self.layers[l].output_dimension})")
            print("\n")
   
    def backpropagation(self, X, target):
        # Forward propagation
        _, caches = self.forward(X)
        
        # Backward propagation 
        L = len(caches)
        Z, A, Z_prev = caches[L-1]
        d = self.layers[L-1].backward(target, Z, A, Z_prev)
        
        for l in reversed(range(0,len(caches)-1)):
            d_prev = d
            d = self.layers[l].backward(d_prev, l, self.layers, caches) 
        
    def forward(self, X): 
        caches = []
        Z = X
        for layer in self.layers:
            Z, A, Z_prev = layer.forward(Z) 
            caches.append((Z, A, Z_prev))
        return Z, caches
                
    def predict(self, X):
        Z, _ = self.forward(X)
        return Z
      
    def pack(self):
        grads = {}
        for l in range(0,len(self.layers)):
            grads["W" + str(l+1)] = self.layers[l].W
            grads["dW" + str(l+1)] = self.layers[l].dW

        return grads

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import ListedColormap
from sklearn.datasets import make_circles, make_classification, make_moons
from sklearn.model_selection import train_test_split

# Create a non-separable data set

#X0, t = make_moons(n_samples=500,noise=0.3, random_state=0)
#X0, t =  make_circles(n_samples=1000, noise=0.1, factor=0.5, random_state=1)

X0, t = make_classification(
    n_features=2, n_redundant=0, n_informative=2, random_state=1, n_clusters_per_class=1
)
rng = np.random.RandomState(2)
X0 += 2 * rng.uniform(size=X0.shape)

X = []
for x in X0:
    X.append([1,x[0],x[1]])


X = np.array(X)
t = np.atleast_2d(t).T


X_train, X_test, t_train, t_test = train_test_split(
        X, t, test_size=0.2, random_state=42
    )

X_train = np.atleast_2d(X_train).T
t_train = np.atleast_2d(t_train).T
X_test = np.atleast_2d(X_test).T
t_test = np.atleast_2d(t_test).T

# %%
# Plot training and testing data
x_min, x_max = X[:, 1].min() - 0.5, X[:, 1].max() + 0.5
y_min, y_max = X[:, 2].min() - 0.5, X[:, 2].max() + 0.5
h = 0.005

figure = plt.figure(figsize=(3, 3))
cm = plt.cm.RdBu
cm_bright = ListedColormap(["#FF0000", "#0000FF"])
ax = plt.subplot(1, 1, 1)
ax.scatter(X_train.T[:,1], X_train.T[:, 2], c=t_train.T, cmap=cm_bright, edgecolors="k")
ax.scatter(X_test.T[:, 1], X_test.T[:, 2], c=t_test.T, cmap=cm_bright, alpha=0.5, edgecolors="k")
ax.set_xlim(x_min, x_max)
ax.set_ylim(y_min, y_max)
ax.set_xticks(())
ax.set_yticks(())
ax.axis('equal');

# %%
# Learning using batch processing

input_layer_dim = [3]
hidden_layers_dim = [40, 20]
output_layer_dim = [1]
layers_dimensions = input_layer_dim + hidden_layers_dim  + output_layer_dim 

nn = mlp(layers_dimensions)

print("Fitting the model:")
alpha = 0.2
epochs = 60000
error = []
ep = []
acc = []
gap = []
for epoch in range(epochs):
    ep.append(epoch)    
    nn.backpropagation(X_train,t_train)
    for l in range(0,len(nn.layers)):
        # Update gradients using GD
        nn.layers[l].W -= alpha * nn.layers[l].dW
    # Compute training error
    y = np.atleast_2d(np.int64(nn.predict(X_train) > 0.5))
    a = np.int64(y.T == t_train.T)
    val1 = 100 - sum(a)/len(a)*100
    error.append(val1)   
    # Compute testing error
    y = np.int64(nn.predict(X_test) > 0.5)
    a = np.int64(y.T ==  t_test.T)
    val2 = 100-sum(a)/len(a)*100
    acc.append(val2)
    gap.append(np.abs(val1-val2)/100)
    
    
    if epoch % 100 == 0:
        print(f"epoch:{epoch:>10}, loss:{np.round(val1[0],2):>6}, %")

        
# Plot training error        
plt.plot(ep, error,'k')
plt.ylabel('Training error  (Ein) %')
plt.xlabel('Epoch')
plt.show()


# Plot testing error        
plt.plot(ep, acc,'k')
plt.ylabel('Testing error  (Ein) %')
plt.xlabel('Epoch')
plt.show()

# Plot testing error        
plt.plot(ep, gap,'k')
plt.ylabel('Gap')
plt.xlabel('Epoch')
plt.show()


# Compute training accuracy
y = np.int64(nn.predict(X_train) > 0.5)
a = np.int64(y.T ==  t_train.T)
accuracy = sum(a)/len(a)*100
print("Training accuracy =", accuracy[0], "%")

# Compute testing accuracy
y = np.int64(nn.predict(X_test) > 0.5)
a = np.int64(y.T ==  t_test.T)
accuracy = sum(a)/len(a)*100
print("Testing accuracy =", np.round(accuracy[0],2), "%")
# Out:
# MLP:
# Hidden_layer 1, shape: (3 x 40)
# Hidden_layer 2, shape: (40 x 20)
# Output_layer 3, shape: (20 x 1)
#
#
# Fitting the model:
# epoch:         0, loss: 48.75, %
# epoch:       100, loss:  3.75, %
# epoch:       200, loss:   5.0, %
# epoch:       300, loss:  3.75, %
# epoch:       400, loss:  3.75, %
# epoch:       500, loss:  3.75, %
# epoch:       600, loss:  3.75, %
# epoch:       700, loss:  3.75, %
# epoch:       800, loss:  3.75, %
# epoch:       900, loss:  3.75, %
# epoch:      1000, loss:  3.75, %
# epoch:      1100, loss:  3.75, %
# epoch:      1200, loss:  3.75, %
# epoch:      1300, loss:  3.75, %
# epoch:      1400, loss:  3.75, %
# epoch:      1500, loss:  3.75, %
# epoch:      1600, loss:  3.75, %
# epoch:      1700, loss:  3.75, %
# epoch:      1800, loss:  3.75, %
# epoch:      1900, loss:  3.75, %
# epoch:      2000, loss:  3.75, %
# epoch:      2100, loss:  3.75, %
# epoch:      2200, loss:  3.75, %
# epoch:      2300, loss:  3.75, %
# epoch:      2400, loss:  3.75, %
# epoch:      2500, loss:  3.75, %
# epoch:      2600, loss:  3.75, %
# epoch:      2700, loss:  3.75, %
# epoch:      2800, loss:  3.75, %
# epoch:      2900, loss:  3.75, %
# epoch:      3000, loss:  3.75, %
# epoch:      3100, loss:  3.75, %
# epoch:      3200, loss:  3.75, %
# epoch:      3300, loss:  3.75, %
# epoch:      3400, loss:  3.75, %
# epoch:      3500, loss:  3.75, %
# epoch:      3600, loss:  3.75, %
# epoch:      3700, loss:  3.75, %
# epoch:      3800, loss:  3.75, %
# epoch:      3900, loss:  3.75, %
# epoch:      4000, loss:  3.75, %
# epoch:      4100, loss:  3.75, %
# epoch:      4200, loss:  3.75, %
# epoch:      4300, loss:  3.75, %
# epoch:      4400, loss:  3.75, %
# epoch:      4500, loss:  3.75, %
# epoch:      4600, loss:  3.75, %
# epoch:      4700, loss:  3.75, %
# epoch:      4800, loss:  3.75, %
# epoch:      4900, loss:  3.75, %
# epoch:      5000, loss:  3.75, %
# epoch:      5100, loss:  3.75, %
# epoch:      5200, loss:  3.75, %
# epoch:      5300, loss:  3.75, %
# epoch:      5400, loss:  3.75, %
# epoch:      5500, loss:  3.75, %
# epoch:      5600, loss:  3.75, %
# epoch:      5700, loss:  3.75, %
# epoch:      5800, loss:  3.75, %
# epoch:      5900, loss:  3.75, %
# epoch:      6000, loss:  3.75, %
# epoch:      6100, loss:  3.75, %
# epoch:      6200, loss:  3.75, %
# epoch:      6300, loss:  3.75, %
# epoch:      6400, loss:  3.75, %
# epoch:      6500, loss:  3.75, %
# epoch:      6600, loss:  3.75, %
# epoch:      6700, loss:  3.75, %
# epoch:      6800, loss:  3.75, %
# epoch:      6900, loss:  3.75, %
# epoch:      7000, loss:  3.75, %
# epoch:      7100, loss:  3.75, %
# epoch:      7200, loss:  3.75, %
# epoch:      7300, loss:  3.75, %
# epoch:      7400, loss:  3.75, %
# epoch:      7500, loss:  3.75, %
# epoch:      7600, loss:  3.75, %
# epoch:      7700, loss:  3.75, %
# epoch:      7800, loss:  3.75, %
# epoch:      7900, loss:  3.75, %
# epoch:      8000, loss:  3.75, %
# epoch:      8100, loss:  3.75, %
# epoch:      8200, loss:  3.75, %
# epoch:      8300, loss:  3.75, %
# epoch:      8400, loss:  3.75, %
# epoch:      8500, loss:  3.75, %
# epoch:      8600, loss:  3.75, %
# epoch:      8700, loss:  3.75, %
# epoch:      8800, loss:  3.75, %
# epoch:      8900, loss:  3.75, %
# epoch:      9000, loss:  3.75, %
# epoch:      9100, loss:  3.75, %
# epoch:      9200, loss:  3.75, %
# epoch:      9300, loss:  3.75, %
# epoch:      9400, loss:  3.75, %
# epoch:      9500, loss:  3.75, %
# epoch:      9600, loss:  3.75, %
# epoch:      9700, loss:  3.75, %
# epoch:      9800, loss:  3.75, %
# epoch:      9900, loss:  3.75, %
# epoch:     10000, loss:  3.75, %
# epoch:     10100, loss:  3.75, %
# epoch:     10200, loss:  3.75, %
# epoch:     10300, loss:  3.75, %
# epoch:     10400, loss:  3.75, %
# epoch:     10500, loss:  3.75, %
# epoch:     10600, loss:  3.75, %
# epoch:     10700, loss:  3.75, %
# epoch:     10800, loss:  3.75, %
# epoch:     10900, loss:  3.75, %
# epoch:     11000, loss:  3.75, %
# epoch:     11100, loss:  3.75, %
# epoch:     11200, loss:  3.75, %
# epoch:     11300, loss:  3.75, %
# epoch:     11400, loss:  3.75, %
# epoch:     11500, loss:  3.75, %
# epoch:     11600, loss:  3.75, %
# epoch:     11700, loss:  3.75, %
# epoch:     11800, loss:  3.75, %
# epoch:     11900, loss:  3.75, %
# epoch:     12000, loss:  3.75, %
# epoch:     12100, loss:  3.75, %
# epoch:     12200, loss:  3.75, %
# epoch:     12300, loss:  3.75, %
# epoch:     12400, loss:  3.75, %
# epoch:     12500, loss:  3.75, %
# epoch:     12600, loss:  3.75, %
# epoch:     12700, loss:  3.75, %
# epoch:     12800, loss:  3.75, %
# epoch:     12900, loss:  3.75, %
# epoch:     13000, loss:  3.75, %
# epoch:     13100, loss:  3.75, %
# epoch:     13200, loss:  3.75, %
# epoch:     13300, loss:  3.75, %
# epoch:     13400, loss:  3.75, %
# epoch:     13500, loss:  3.75, %
# epoch:     13600, loss:  3.75, %
# epoch:     13700, loss:  3.75, %
# epoch:     13800, loss:  3.75, %
# epoch:     13900, loss:   5.0, %
# epoch:     14000, loss:  3.75, %
# epoch:     14100, loss:  3.75, %
# epoch:     14200, loss:  3.75, %
# epoch:     14300, loss:  3.75, %
# epoch:     14400, loss:  3.75, %
# epoch:     14500, loss:  3.75, %
# epoch:     14600, loss:  3.75, %
# epoch:     14700, loss:  3.75, %
# epoch:     14800, loss:  3.75, %
# epoch:     14900, loss:  3.75, %
# epoch:     15000, loss:  3.75, %
# epoch:     15100, loss:  3.75, %
# epoch:     15200, loss:  3.75, %
# epoch:     15300, loss:  3.75, %
# epoch:     15400, loss:  3.75, %
# epoch:     15500, loss:  3.75, %
# epoch:     15600, loss:   2.5, %
# epoch:     15700, loss:   2.5, %
# epoch:     15800, loss:   2.5, %
# epoch:     15900, loss:   2.5, %
# epoch:     16000, loss:   2.5, %
# epoch:     16100, loss:   2.5, %
# epoch:     16200, loss:   2.5, %
# epoch:     16300, loss:   2.5, %
# epoch:     16400, loss:   2.5, %
# epoch:     16500, loss:   2.5, %
# epoch:     16600, loss:   2.5, %
# epoch:     16700, loss:   2.5, %
# epoch:     16800, loss:   2.5, %
# epoch:     16900, loss:   2.5, %
# epoch:     17000, loss:   2.5, %
# epoch:     17100, loss:   2.5, %
# epoch:     17200, loss:   2.5, %
# epoch:     17300, loss:   2.5, %
# epoch:     17400, loss:   2.5, %
# epoch:     17500, loss:   2.5, %
# epoch:     17600, loss:   2.5, %
# epoch:     17700, loss:   2.5, %
# epoch:     17800, loss:   2.5, %
# epoch:     17900, loss:   2.5, %
# epoch:     18000, loss:   2.5, %
# epoch:     18100, loss:   2.5, %
# epoch:     18200, loss:   2.5, %
# epoch:     18300, loss:   2.5, %
# epoch:     18400, loss:   2.5, %
# epoch:     18500, loss:   2.5, %
# epoch:     18600, loss:   2.5, %
# epoch:     18700, loss:   2.5, %
# epoch:     18800, loss:   2.5, %
# epoch:     18900, loss:   2.5, %
# epoch:     19000, loss:   2.5, %
# epoch:     19100, loss:   2.5, %
# epoch:     19200, loss:   2.5, %
# epoch:     19300, loss:   2.5, %
# epoch:     19400, loss:   2.5, %
# epoch:     19500, loss:  1.25, %
# epoch:     19600, loss:   0.0, %
# epoch:     19700, loss:   0.0, %
# epoch:     19800, loss:   0.0, %
# epoch:     19900, loss:  1.25, %
# epoch:     20000, loss:   0.0, %
# epoch:     20100, loss:  1.25, %
# epoch:     20200, loss:   0.0, %
# epoch:     20300, loss:   0.0, %
# epoch:     20400, loss:   0.0, %
# epoch:     20500, loss:   0.0, %
# epoch:     20600, loss:   0.0, %
# epoch:     20700, loss:   0.0, %
# epoch:     20800, loss:   0.0, %
# epoch:     20900, loss:   0.0, %
# epoch:     21000, loss:   0.0, %
# epoch:     21100, loss:   0.0, %
# epoch:     21200, loss:   0.0, %
# epoch:     21300, loss:   0.0, %
# epoch:     21400, loss:   0.0, %
# epoch:     21500, loss:   0.0, %
# epoch:     21600, loss:   0.0, %
# epoch:     21700, loss:   0.0, %
# epoch:     21800, loss:   0.0, %
# epoch:     21900, loss:   0.0, %
# epoch:     22000, loss:   0.0, %
# epoch:     22100, loss:   0.0, %
# epoch:     22200, loss:   0.0, %
# epoch:     22300, loss:   0.0, %
# epoch:     22400, loss:   0.0, %
# epoch:     22500, loss:   0.0, %
# epoch:     22600, loss:   0.0, %
# epoch:     22700, loss:   0.0, %
# epoch:     22800, loss:   0.0, %
# epoch:     22900, loss:   0.0, %
# epoch:     23000, loss:   0.0, %
# epoch:     23100, loss:   0.0, %
# epoch:     23200, loss:   0.0, %
# epoch:     23300, loss:   0.0, %
# epoch:     23400, loss:   0.0, %
# epoch:     23500, loss:   0.0, %
# epoch:     23600, loss:   0.0, %
# epoch:     23700, loss:   0.0, %
# epoch:     23800, loss:   0.0, %
# epoch:     23900, loss:   0.0, %
# epoch:     24000, loss:   0.0, %
# epoch:     24100, loss:   0.0, %
# epoch:     24200, loss:   0.0, %
# epoch:     24300, loss:   0.0, %
# epoch:     24400, loss:   0.0, %
# epoch:     24500, loss:   0.0, %
# epoch:     24600, loss:   0.0, %
# epoch:     24700, loss:   0.0, %
# epoch:     24800, loss:   0.0, %
# epoch:     24900, loss:   0.0, %
# epoch:     25000, loss:   0.0, %
# epoch:     25100, loss:   0.0, %
# epoch:     25200, loss:   0.0, %
# epoch:     25300, loss:   0.0, %
# epoch:     25400, loss:   0.0, %
# epoch:     25500, loss:   0.0, %
# epoch:     25600, loss:   0.0, %
# epoch:     25700, loss:   0.0, %
# epoch:     25800, loss:   0.0, %
# epoch:     25900, loss:   0.0, %
# epoch:     26000, loss:   0.0, %
# epoch:     26100, loss:   0.0, %
# epoch:     26200, loss:   0.0, %
# epoch:     26300, loss:   0.0, %
# epoch:     26400, loss:   0.0, %
# epoch:     26500, loss:   0.0, %
# epoch:     26600, loss:   0.0, %
# epoch:     26700, loss:   0.0, %
# epoch:     26800, loss:   0.0, %
# epoch:     26900, loss:   0.0, %
# epoch:     27000, loss:   0.0, %
# epoch:     27100, loss:   0.0, %
# epoch:     27200, loss:   0.0, %
# epoch:     27300, loss:   0.0, %
# epoch:     27400, loss:   0.0, %
# epoch:     27500, loss:   0.0, %
# epoch:     27600, loss:   0.0, %
# epoch:     27700, loss:   0.0, %
# epoch:     27800, loss:   0.0, %
# epoch:     27900, loss:   0.0, %
# epoch:     28000, loss:   0.0, %
# epoch:     28100, loss:   0.0, %
# epoch:     28200, loss:   0.0, %
# epoch:     28300, loss:   0.0, %
# epoch:     28400, loss:   0.0, %
# epoch:     28500, loss:   0.0, %
# epoch:     28600, loss:   0.0, %
# epoch:     28700, loss:   0.0, %
# epoch:     28800, loss:   0.0, %
# epoch:     28900, loss:   0.0, %
# epoch:     29000, loss:   0.0, %
# epoch:     29100, loss:   0.0, %
# epoch:     29200, loss:   0.0, %
# epoch:     29300, loss:   0.0, %
# epoch:     29400, loss:   0.0, %
# epoch:     29500, loss:   0.0, %
# epoch:     29600, loss:   0.0, %
# epoch:     29700, loss:   0.0, %
# epoch:     29800, loss:   0.0, %
# epoch:     29900, loss:   0.0, %
# epoch:     30000, loss:   0.0, %
# epoch:     30100, loss:   0.0, %
# epoch:     30200, loss:   0.0, %
# epoch:     30300, loss:   0.0, %
# epoch:     30400, loss:   0.0, %
# epoch:     30500, loss:   0.0, %
# epoch:     30600, loss:   0.0, %
# epoch:     30700, loss:   0.0, %
# epoch:     30800, loss:   0.0, %
# epoch:     30900, loss:   0.0, %
# epoch:     31000, loss:   0.0, %
# epoch:     31100, loss:   0.0, %
# epoch:     31200, loss:   0.0, %
# epoch:     31300, loss:   0.0, %
# epoch:     31400, loss:   0.0, %
# epoch:     31500, loss:   0.0, %
# epoch:     31600, loss:   0.0, %
# epoch:     31700, loss:   0.0, %
# epoch:     31800, loss:   0.0, %
# epoch:     31900, loss:   0.0, %
# epoch:     32000, loss:   0.0, %
# epoch:     32100, loss:   0.0, %
# epoch:     32200, loss:   0.0, %
# epoch:     32300, loss:   0.0, %
# epoch:     32400, loss:   0.0, %
# epoch:     32500, loss:   0.0, %
# epoch:     32600, loss:   0.0, %
# epoch:     32700, loss:   0.0, %
# epoch:     32800, loss:   0.0, %
# epoch:     32900, loss:   0.0, %
# epoch:     33000, loss:   0.0, %
# epoch:     33100, loss:   0.0, %
# epoch:     33200, loss:   0.0, %
# epoch:     33300, loss:   0.0, %
# epoch:     33400, loss:   0.0, %
# epoch:     33500, loss:   0.0, %
# epoch:     33600, loss:   0.0, %
# epoch:     33700, loss:   0.0, %
# epoch:     33800, loss:   0.0, %
# epoch:     33900, loss:   0.0, %
# epoch:     34000, loss:   0.0, %
# epoch:     34100, loss:   0.0, %
# epoch:     34200, loss:   0.0, %
# epoch:     34300, loss:   0.0, %
# epoch:     34400, loss:   0.0, %
# epoch:     34500, loss:   0.0, %
# epoch:     34600, loss:   0.0, %
# epoch:     34700, loss:   0.0, %
# epoch:     34800, loss:   0.0, %
# epoch:     34900, loss:   0.0, %
# epoch:     35000, loss:   0.0, %
# epoch:     35100, loss:   0.0, %
# epoch:     35200, loss:   0.0, %
# epoch:     35300, loss:   0.0, %
# epoch:     35400, loss:   0.0, %
# epoch:     35500, loss:   0.0, %
# epoch:     35600, loss:   0.0, %
# epoch:     35700, loss:   0.0, %
# epoch:     35800, loss:   0.0, %
# epoch:     35900, loss:   0.0, %
# epoch:     36000, loss:   0.0, %
# epoch:     36100, loss:   0.0, %
# epoch:     36200, loss:   0.0, %
# epoch:     36300, loss:   0.0, %
# epoch:     36400, loss:   0.0, %
# epoch:     36500, loss:   0.0, %
# epoch:     36600, loss:   0.0, %
# epoch:     36700, loss:   0.0, %
# epoch:     36800, loss:   0.0, %
# epoch:     36900, loss:   0.0, %
# epoch:     37000, loss:   0.0, %
# epoch:     37100, loss:   0.0, %
# epoch:     37200, loss:   0.0, %
# epoch:     37300, loss:   0.0, %
# epoch:     37400, loss:   0.0, %
# epoch:     37500, loss:   0.0, %
# epoch:     37600, loss:   0.0, %
# epoch:     37700, loss:   0.0, %
# epoch:     37800, loss:   0.0, %
# epoch:     37900, loss:   0.0, %
# epoch:     38000, loss:   0.0, %
# epoch:     38100, loss:   0.0, %
# epoch:     38200, loss:   0.0, %
# epoch:     38300, loss:   0.0, %
# epoch:     38400, loss:   0.0, %
# epoch:     38500, loss:   0.0, %
# epoch:     38600, loss:   0.0, %
# epoch:     38700, loss:   0.0, %
# epoch:     38800, loss:   0.0, %
# epoch:     38900, loss:   0.0, %
# epoch:     39000, loss:   0.0, %
# epoch:     39100, loss:   0.0, %
# epoch:     39200, loss:   0.0, %
# epoch:     39300, loss:   0.0, %
# epoch:     39400, loss:   0.0, %
# epoch:     39500, loss:   0.0, %
# epoch:     39600, loss:   0.0, %
# epoch:     39700, loss:   0.0, %
# epoch:     39800, loss:   0.0, %
# epoch:     39900, loss:   0.0, %
# epoch:     40000, loss:   0.0, %
# epoch:     40100, loss:   0.0, %
# epoch:     40200, loss:   0.0, %
# epoch:     40300, loss:   0.0, %
# epoch:     40400, loss:   0.0, %
# epoch:     40500, loss:   0.0, %
# epoch:     40600, loss:   0.0, %
# epoch:     40700, loss:   0.0, %
# epoch:     40800, loss:   0.0, %
# epoch:     40900, loss:   0.0, %
# epoch:     41000, loss:   0.0, %
# epoch:     41100, loss:   0.0, %
# epoch:     41200, loss:   0.0, %
# epoch:     41300, loss:   0.0, %
# epoch:     41400, loss:   0.0, %
# epoch:     41500, loss:   0.0, %
# epoch:     41600, loss:   0.0, %
# epoch:     41700, loss:   0.0, %
# epoch:     41800, loss:   0.0, %
# epoch:     41900, loss:   0.0, %
# epoch:     42000, loss:   0.0, %
# epoch:     42100, loss:   0.0, %
# epoch:     42200, loss:   0.0, %
# epoch:     42300, loss:   0.0, %
# epoch:     42400, loss:   0.0, %
# epoch:     42500, loss:   0.0, %
# epoch:     42600, loss:   0.0, %
# epoch:     42700, loss:   0.0, %
# epoch:     42800, loss:   0.0, %
# epoch:     42900, loss:   0.0, %
# epoch:     43000, loss:   0.0, %
# epoch:     43100, loss:   0.0, %
# epoch:     43200, loss:   0.0, %
# epoch:     43300, loss:   0.0, %
# epoch:     43400, loss:   0.0, %
# epoch:     43500, loss:   0.0, %
# epoch:     43600, loss:   0.0, %
# epoch:     43700, loss:   0.0, %
# epoch:     43800, loss:   0.0, %
# epoch:     43900, loss:   0.0, %
# epoch:     44000, loss:   0.0, %
# epoch:     44100, loss:   0.0, %
# epoch:     44200, loss:   0.0, %
# epoch:     44300, loss:   0.0, %
# epoch:     44400, loss:   0.0, %
# epoch:     44500, loss:   0.0, %
# epoch:     44600, loss:   0.0, %
# epoch:     44700, loss:   0.0, %
# epoch:     44800, loss:   0.0, %
# epoch:     44900, loss:   0.0, %
# epoch:     45000, loss:   0.0, %
# epoch:     45100, loss:   0.0, %
# epoch:     45200, loss:   0.0, %
# epoch:     45300, loss:   0.0, %
# epoch:     45400, loss:   0.0, %
# epoch:     45500, loss:   0.0, %
# epoch:     45600, loss:   0.0, %
# epoch:     45700, loss:   0.0, %
# epoch:     45800, loss:   0.0, %
# epoch:     45900, loss:   0.0, %
# epoch:     46000, loss:   0.0, %
# epoch:     46100, loss:   0.0, %
# epoch:     46200, loss:   0.0, %
# epoch:     46300, loss:   0.0, %
# epoch:     46400, loss:   0.0, %
# epoch:     46500, loss:   0.0, %
# epoch:     46600, loss:   0.0, %
# epoch:     46700, loss:   0.0, %
# epoch:     46800, loss:   0.0, %
# epoch:     46900, loss:   0.0, %
# epoch:     47000, loss:   0.0, %
# epoch:     47100, loss:   0.0, %
# epoch:     47200, loss:   0.0, %
# epoch:     47300, loss:   0.0, %
# epoch:     47400, loss:   0.0, %
# epoch:     47500, loss:   0.0, %
# epoch:     47600, loss:   0.0, %
# epoch:     47700, loss:   0.0, %
# epoch:     47800, loss:   0.0, %
# epoch:     47900, loss:   0.0, %
# epoch:     48000, loss:   0.0, %
# epoch:     48100, loss:   0.0, %
# epoch:     48200, loss:   0.0, %
# epoch:     48300, loss:   0.0, %
# epoch:     48400, loss:   0.0, %
# epoch:     48500, loss:   0.0, %
# epoch:     48600, loss:   0.0, %
# epoch:     48700, loss:   0.0, %
# epoch:     48800, loss:   0.0, %
# epoch:     48900, loss:   0.0, %
# epoch:     49000, loss:   0.0, %
# epoch:     49100, loss:   0.0, %
# epoch:     49200, loss:   0.0, %
# epoch:     49300, loss:   0.0, %
# epoch:     49400, loss:   0.0, %
# epoch:     49500, loss:   0.0, %
# epoch:     49600, loss:   0.0, %
# epoch:     49700, loss:   0.0, %
# epoch:     49800, loss:   0.0, %
# epoch:     49900, loss:   0.0, %
# epoch:     50000, loss:   0.0, %
# epoch:     50100, loss:   0.0, %
# epoch:     50200, loss:   0.0, %
# epoch:     50300, loss:   0.0, %
# epoch:     50400, loss:   0.0, %
# epoch:     50500, loss:   0.0, %
# epoch:     50600, loss:   0.0, %
# epoch:     50700, loss:   0.0, %
# epoch:     50800, loss:   0.0, %
# epoch:     50900, loss:   0.0, %
# epoch:     51000, loss:   0.0, %
# epoch:     51100, loss:   0.0, %
# epoch:     51200, loss:   0.0, %
# epoch:     51300, loss:   0.0, %
# epoch:     51400, loss:   0.0, %
# epoch:     51500, loss:   0.0, %
# epoch:     51600, loss:   0.0, %
# epoch:     51700, loss:   0.0, %
# epoch:     51800, loss:   0.0, %
# epoch:     51900, loss:   0.0, %
# epoch:     52000, loss:   0.0, %
# epoch:     52100, loss:   0.0, %
# epoch:     52200, loss:   0.0, %
# epoch:     52300, loss:   0.0, %
# epoch:     52400, loss:   0.0, %
# epoch:     52500, loss:   0.0, %
# epoch:     52600, loss:   0.0, %
# epoch:     52700, loss:   0.0, %
# epoch:     52800, loss:   0.0, %
# epoch:     52900, loss:   0.0, %
# epoch:     53000, loss:   0.0, %
# epoch:     53100, loss:   0.0, %
# epoch:     53200, loss:   0.0, %
# epoch:     53300, loss:   0.0, %
# epoch:     53400, loss:   0.0, %
# epoch:     53500, loss:   0.0, %
# epoch:     53600, loss:   0.0, %
# epoch:     53700, loss:   0.0, %
# epoch:     53800, loss:   0.0, %
# epoch:     53900, loss:   0.0, %
# epoch:     54000, loss:   0.0, %
# epoch:     54100, loss:   0.0, %
# epoch:     54200, loss:   0.0, %
# epoch:     54300, loss:   0.0, %
# epoch:     54400, loss:   0.0, %
# epoch:     54500, loss:   0.0, %
# epoch:     54600, loss:   0.0, %
# epoch:     54700, loss:   0.0, %
# epoch:     54800, loss:   0.0, %
# epoch:     54900, loss:   0.0, %
# epoch:     55000, loss:   0.0, %
# epoch:     55100, loss:   0.0, %
# epoch:     55200, loss:   0.0, %
# epoch:     55300, loss:   0.0, %
# epoch:     55400, loss:   0.0, %
# epoch:     55500, loss:   0.0, %
# epoch:     55600, loss:   0.0, %
# epoch:     55700, loss:   0.0, %
# epoch:     55800, loss:   0.0, %
# epoch:     55900, loss:   0.0, %
# epoch:     56000, loss:   0.0, %
# epoch:     56100, loss:   0.0, %
# epoch:     56200, loss:   0.0, %
# epoch:     56300, loss:   0.0, %
# epoch:     56400, loss:   0.0, %
# epoch:     56500, loss:   0.0, %
# epoch:     56600, loss:   0.0, %
# epoch:     56700, loss:   0.0, %
# epoch:     56800, loss:   0.0, %
# epoch:     56900, loss:   0.0, %
# epoch:     57000, loss:   0.0, %
# epoch:     57100, loss:   0.0, %
# epoch:     57200, loss:   0.0, %
# epoch:     57300, loss:   0.0, %
# epoch:     57400, loss:   0.0, %
# epoch:     57500, loss:   0.0, %
# epoch:     57600, loss:   0.0, %
# epoch:     57700, loss:   0.0, %
# epoch:     57800, loss:   0.0, %
# epoch:     57900, loss:   0.0, %
# epoch:     58000, loss:   0.0, %
# epoch:     58100, loss:   0.0, %
# epoch:     58200, loss:   0.0, %
# epoch:     58300, loss:   0.0, %
# epoch:     58400, loss:   0.0, %
# epoch:     58500, loss:   0.0, %
# epoch:     58600, loss:   0.0, %
# epoch:     58700, loss:   0.0, %
# epoch:     58800, loss:   0.0, %
# epoch:     58900, loss:   0.0, %
# epoch:     59000, loss:   0.0, %
# epoch:     59100, loss:   0.0, %
# epoch:     59200, loss:   0.0, %
# epoch:     59300, loss:   0.0, %
# epoch:     59400, loss:   0.0, %
# epoch:     59500, loss:   0.0, %
# epoch:     59600, loss:   0.0, %
# epoch:     59700, loss:   0.0, %
# epoch:     59800, loss:   0.0, %
# epoch:     59900, loss:   0.0, %
# Training accuracy = 100.0 %
# Testing accuracy = 95.0 %

# %%
# Plot classification boundary
x_min, x_max = X[:, 1].min() - 0.5, X[:, 1].max() + 0.5
y_min, y_max = X[:, 2].min() - 0.5, X[:, 2].max() + 0.5
h = 0.005


Xp = []
for x in np.arange(x_min, x_max, h):
    for y in np.arange(y_min, y_max, h):
        Xp.append([1, x, y])

Xp = np.atleast_2d(Xp).T
yy = nn.predict(Xp)
yp = np.int64(yy > 0.5)      

figure = plt.figure(figsize=(4, 4))
cm = plt.cm.RdBu
cm_bright = ListedColormap(["#FF0000", "#0000FF"])
ax = plt.subplot(1, 1, 1)
ax.scatter(Xp.T[:,1], Xp.T[:, 2], c=yy.T, cmap=cm_bright, alpha=0.4,)

ax.scatter(X_train.T[:,1], X_train.T[:, 2], c=t_train.T, cmap=cm_bright, edgecolors="k")
ax.scatter(X_test.T[:, 1], X_test.T[:, 2], c=t_test.T, cmap=cm_bright, alpha=0.5, edgecolors="k")
ax.set_xlim(x_min, x_max)
ax.set_ylim(y_min, y_max)
ax.set_xticks(())
ax.set_yticks(())
ax.axis('equal');
ax.axis('off');

# %%
figure = plt.figure(figsize=(3, 3))
cm = plt.cm.RdBu
cm_bright = ListedColormap(["#FF0000", "#0000FF"])
ax = plt.subplot(1, 1, 1)
ax.scatter(X_train.T[:,1], X_train.T[:, 2], c=t_train.T, cmap=cm_bright, edgecolors="k")
ax.scatter(X_test.T[:, 1], X_test.T[:, 2], c=t_test.T, cmap=cm_bright, alpha=0.5, edgecolors="k")
ax.set_xlim(x_min, x_max)
ax.set_ylim(y_min, y_max)
ax.set_xticks(())
ax.set_yticks(())
ax.axis('equal');

# %%
# Contour plot
h = 0.01
xx, yy = np.meshgrid(np.arange(-5, 5, h), np.arange(-5, 5, h))


XY = []
for x in np.arange(-5, 5, h):
    for y in np.arange(-5, 5, h):
        XY.append([1, x, y])

XY = np.array(XY).T
Z = np.array(nn.predict(XY))
Z=Z.reshape(xx.shape).T

figure = plt.figure(figsize=(4, 4))
cm = plt.cm.RdBu
cm_bright = ListedColormap(["#FF0000", "#0000FF"])
ax = plt.subplot(1, 1, 1)
ax.contourf(xx, yy, Z, cmap=plt.cm.RdBu, alpha=0.9, levels = 5)
ax.scatter(X_train.T[:,1], X_train.T[:, 2], c=t_train.T, cmap=cm_bright, edgecolors="k")
ax.scatter(X_test.T[:, 1], X_test.T[:, 2], c=t_test.T, cmap=cm_bright, alpha=0.5, edgecolors="k")
ax.axis('equal');
ax.axis('off');
